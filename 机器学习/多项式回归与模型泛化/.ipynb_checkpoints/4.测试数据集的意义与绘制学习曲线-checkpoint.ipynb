# %% [markdown]
# ## 测试数据集的意义
#
#
# 过拟合的情况下所的模型的泛化能力差
#
# 机器学习主要解决的是过拟合的问题

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
x = np.linspace(-3, 3, 100)
X = x.reshape(-1,1)
y = 0.5*x**2 + x + 1 + np.random.normal(0,1,size=100)

plt.scatter(X, y, color='blue')

# %%
def PolynomialRegression(degree):
    return Pipeline([
        ("Poly", PolynomialFeatures(degree=degree)),
        ("Standar", StandardScaler()),
        ("lin_reg", LinearRegression())
    ])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 666)

poly2_reg=PolynomialRegression(2)
poly2_reg.fit(X_train,y_train)
y2_predict = poly2_reg.predict(X_test)
mean_squared_error(y2_predict, y_test)
# Out:
# 0.8072742394349075

# %%
poly10_reg=PolynomialRegression(10)
poly10_reg.fit(X_train,y_train)
y10_predict = poly10_reg.predict(X_test)
mean_squared_error(y10_predict, y_test)
# Out:
# 0.8670574087050482

# %%
poly100_reg=PolynomialRegression(100)
poly100_reg.fit(X_train,y_train)
y100_predict = poly100_reg.predict(X_test)
mean_squared_error(y100_predict, y_test)
# Out:
# 1.1126189802485567e+19

# %% [markdown]
# ###  对于多项式回归，阶数表示的是模型的复杂度
#
# ![image.png](attachment:image.png)
#
# - 欠拟合（underfitting）
#
#     算法所训练的模型不能完整表述数据关系
# - 过拟合（overfitting）
#
#     算法所训练的模型过多的表达了数据间的噪音关系

# %% [markdown]
# ### 学习如何绘制学习曲线

# %%
plt.scatter(X, y, color='blue')

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 10)
X_train.shape
# Out:
# (75, 1)

# %%
train_score=[]
test_score = []
for i in range(1, 76):
    lin_reg = LinearRegression()
    lin_reg.fit(X_train[:i], y_train[:i])
    
    y_train_predict = lin_reg.predict(X_train[:i])
    train_score.append(mean_squared_error(y_train[:i],y_train_predict))
    
    y_test_predct = lin_reg.predict(X_test)
    test_score.append(mean_squared_error(y_test,y_test_predct))

# %%
plt.plot([i for i in range(1,76)], np.sqrt(train_score), label = "train")
plt.plot([i for i in range(1,76)], np.sqrt(test_score), label = "test")

# %%
def plot_learning_curve(algo, X_train, X_test, y_train, y_test):
    train_score=[]
    test_score = []
    for i in range(1, len(X_train)+1):

        algo.fit(X_train[:i], y_train[:i])

        y_train_predict = algo.predict(X_train[:i])
        train_score.append(mean_squared_error(y_train[:i],y_train_predict))

        y_test_predct = algo.predict(X_test)
        test_score.append(mean_squared_error(y_test,y_test_predct))
    
    plt.plot([i for i in range(1,len(X_train)+1)], np.sqrt(train_score), label = "train")
    plt.plot([i for i in range(1,len(X_train)+1)], np.sqrt(test_score), label = "test")
    
    plt.legend()
    plt.axis([0, len(X_train)+1, 0 , 4])
    plt.show()

# %%
poly2_reg = PolynomialRegression(degree=2)
plot_learning_curve(poly2_reg,X_train,X_test,y_train,y_test)

# %%
poly20_reg = PolynomialRegression(degree=20)
plot_learning_curve(poly20_reg,X_train,X_test,y_train,y_test)
